# %%
import pandas as pd

df = pd.read_excel('/home/michel/Documentos/Projetos pessoais/excel_for_dbdiagram/excel_files/jobs_schema_sql_pentaho_v4.ods')
df.head()
# Out:
#   index_original index_table index_coluna index_tipos         job fatdim  \
# 0            124           1           13         532  sql_server      F
# 1            805           2           15         534  sql_server      F
# 2            135           3          205         604  sql_server      F
# 3            816           4          207         606  sql_server      F
# 4            121           5          217         613  sql_server      F
#
#                            schemas     tabela                 coluna tipo  \
# 0  datamart_inteligencia_comercial  agr_movel           ano_operacao  int
# 1  datamart_inteligencia_comercial  agr_movel           ano_operacao  int
# 2  datamart_inteligencia_comercial  agr_movel  cod_equipe_venda_foto  int
# 3  datamart_inteligencia_comercial  agr_movel  cod_equipe_venda_foto  int
# 4  datamart_inteligencia_comercial  agr_movel    cod_grupo_comercial  int
#
#   metrica(fato) dimensão      tabela_no_dw relacionamento  \
# ...
